# %% [markdown]
# # Optional Lab: Classification
#
# In this lab, you will contrast regression and classification.

# %%
# %pip install numpy==1.24.0 matplotlib==3.6.0 ipympl
# Out:
# Requirement already satisfied: numpy==1.24.0 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (1.24.0)
# Requirement already satisfied: matplotlib==3.6.0 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (3.6.0)
# Requirement already satisfied: ipympl in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (0.9.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from matplotlib==3.6.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from matplotlib==3.6.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from matplotlib==3.6.0) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from matplotlib==3.6.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from matplotlib==3.6.0) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from matplotlib==3.6.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from matplotlib==3.6.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from matplotlib==3.6.0) (2.9.0.post0)
# Requirement already satisfied: ipython<9 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipympl) (8.35.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipympl) (8.1.5)
# Requirement already satisfied: traitlets<6 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipython<9->ipympl) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipython<9->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipython<9->ipympl) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipython<9->ipympl) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipython<9->ipympl) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipython<9->ipympl) (2.19.1)
# Requirement already satisfied: stack_data in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipython<9->ipympl) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipython<9->ipympl) (4.13.1)
# Requirement already satisfied: comm>=0.1.3 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.13)
# Requirement already satisfied: six>=1.5 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.6.0) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<9->ipympl) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from stack_data->ipython<9->ipympl) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from stack_data->ipython<9->ipympl) (3.0.0)
# Requirement already satisfied: pure_eval in /Users/thrmn/Downloads/CS/coursera-ml-course/.conda/lib/python3.11/site-packages (from stack_data->ipython<9->ipympl) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip list
# Out:
# Package                 Version
# ----------------------- -----------
# appnope                 0.1.4
# asttokens               3.0.0
# comm                    0.2.2
# contourpy               1.3.1
# cycler                  0.12.1
# debugpy                 1.8.11
# decorator               5.2.1
# exceptiongroup          1.2.2
# executing               2.1.0
# fonttools               4.57.0
# importlib_metadata      8.6.1
# ipykernel               6.29.5
# ipympl                  0.9.5
# ipython                 8.35.0
# ipython_pygments_lexers 1.1.1
# ipywidgets              8.1.5
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.7.2
# jupyterlab_widgets      3.0.13
# kiwisolver              1.4.8
# matplotlib              3.6.0
# matplotlib-inline       0.1.7
# nest_asyncio            1.6.0
# numpy                   1.24.0
# packaging               24.2
# parso                   0.8.4
# pexpect                 4.9.0
# pickleshare             0.7.5
# pillow                  11.1.0
# pip                     25.0
# platformdirs            4.3.7
# prompt_toolkit          3.0.50
# psutil                  5.9.0
# ptyprocess              0.7.0
# pure_eval               0.2.3
# Pygments                2.19.1
# pyparsing               3.2.3
# python-dateutil         2.9.0.post0
# pyzmq                   26.2.0
# setuptools              75.8.0
# six                     1.17.0
# stack_data              0.6.3
# tornado                 6.4.2
# traitlets               5.14.3
# typing_extensions       4.13.1
# wcwidth                 0.2.13
# wheel                   0.45.1
# widgetsnbextension      4.0.13
# zipp                    3.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
# %matplotlib widget
# %matplotlib ipympl
import matplotlib.pyplot as plt
from lab_utils_common import dlc, plot_data
from plt_one_addpt_onclick import plt_one_addpt_onclick
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# <!-- ## Classification Problems
# <img align="left" src="./images/C1_W3_Classification.png"     style=" width:380px; padding: 10px; " > Examples of classification problems are things like: identifying email as Spam or Not Spam or determining if a tumor is malignant or benign. In particular, these are examples of *binary* classification where there are two possible outcomes.  Outcomes can be  described in pairs of 'positive'/'negative' such as 'yes'/'no, 'true'/'false' or '1'/'0'.
#
# Plots of classification data sets often use symbols to indicate the outcome of an example. In the plots below, 'X' is used to represent the positive values while 'O' represents negative outcomes.  -->

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos = y_train == 1
neg = y_train == 0

fig,ax = plt.subplots(1,2,figsize=(8,3))
#plot 1, single variable
ax[0].scatter(x_train[pos], y_train[pos], marker='x', s=80, c = 'red', label="y=1")
ax[0].scatter(x_train[neg], y_train[neg], marker='o', s=100, label="y=0", facecolors='none', 
              edgecolors=dlc["dlblue"],lw=3)

ax[0].set_ylim(-0.08,1.1)
ax[0].set_ylabel('y', fontsize=12)
ax[0].set_xlabel('x', fontsize=12)
ax[0].set_title('one variable plot')
ax[0].legend()

#plot 2, two variables
plot_data(X_train2, y_train2, ax[1])
ax[1].axis([0, 4, 0, 4])
ax[1].set_ylabel('$x_1$', fontsize=12)
ax[1].set_xlabel('$x_0$', fontsize=12)
ax[1].set_title('two variable plot')
ax[1].legend()
plt.tight_layout()
plt.show()
print(ax)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
# [<AxesSubplot: title={'center': 'one variable plot'}, xlabel='x', ylabel='y'>
#  <AxesSubplot: title={'center': 'two variable plot'}, xlabel='$x_0$', ylabel='$x_1$'>]

# %% [markdown]
# Note in the plots above:
# - In the single variable plot, positive results are shown both a red 'X's and as y=1. Negative results are blue 'O's and are located at y=0.
#    - Recall in the case of linear regression, y would not have been limited to two values but could have been any value.
# - In the two-variable plot, the y axis is not available.  Positive results are shown as red 'X's, while negative results use the blue 'O' symbol.
#     - Recall in the case of linear regression with multiple variables, y would not have been limited to two values and a similar plot would have been three-dimensional.

# %% [markdown]
# ## Linear Regression approach
# In the previous week, you applied linear regression to build a prediction model. Let's try that approach here using the simple example that was described in the lecture. The model will predict if a tumor is benign or malignant based on tumor size.  Try the following:
# - Click on 'Run Linear Regression' to find the best linear regression model for the given data.
#     - Note the resulting linear model does **not** match the data well.
# One option to improve the results is to apply a *threshold*.
# - Tick the box on the 'Toggle 0.5 threshold' to show the predictions if a threshold is applied.
#     - These predictions look good, the predictions match the data
# - *Important*: Now, add further 'malignant' data points on the far right, in the large tumor size range (near 10), and re-run linear regression.
#     - Now, the model predicts the larger tumor, but data point at x=3 is being incorrectly predicted!
# - to clear/renew the plot, rerun the cell containing the plot command.

# %%
w_in = np.zeros((1))
b_in = 0
plt.close('all') 
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=False)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %% [markdown]
# The example above demonstrates that the linear model is insufficient to model categorical data. The model can be extended as described in the following lab.

# %% [markdown]
# ## Congratulations!
# In this lab you:
# - explored categorical data sets and plotting
# - determined that linear regression was insufficient for a classification problem.
